# %%
ord(' ')
# Out:
# 32

# %%
with open('data.txt','r') as file:
    data = file.read()
    for char in data:
        if not char.isalnum() and not ord(char)==32:
            data = data.replace(char,'')
            # print(data)
            # print()
print(data)
# Out:
# hello my naem is rajrajeshwarikhatawate
