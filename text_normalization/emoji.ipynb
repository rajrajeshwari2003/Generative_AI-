# %%
import emoji

# %%
s = 'helloo😂'
emoji.replace_emoji(s,"")
# Out:
# 'helloo'

# %%
r = 'hello raj💕👍'
emoji.replace_emoji(r,"")
# Out:
# 'hello raj'

# %%
# we can handle this 
r = 'hello raj💕👍'
emoji.demojize(r)
# Out:
# 'hello raj:two_hearts::thumbs_up:'

# %%
r = 'hello!😒😁🙌'
emoji.demojize(r)
# Out:
# 'hello!:unamused_face::beaming_face_with_smiling_eyes::raising_hands:'
