# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
words = [
    "running", "runner", "ran", "flies", "flying", "happily", "happiness",
    "cats", "dogs", "buses", "bushy", "bushes", "caring", "care",
    "universal", "universally", "study", "studying", "studies", "better"
]

for word in words:
    print(f'{words} ---> {stemmer.stem(word)}')

# stemmed_words = [stemmer.stem(word) for word in words]

# for word, stem in zip(words, stemmed_words):
#     print(f"{word} -> {stem}")
# Out:
# ['running', 'runner', 'ran', 'flies', 'flying', 'happily', 'happiness', 'cats', 'dogs', 'buses', 'bushy', 'bushes', 'caring', 'care', 'universal', 'universally', 'study', 'studying', 'studies', 'better'] ---> run
# ['running', 'runner', 'ran', 'flies', 'flying', 'happily', 'happiness', 'cats', 'dogs', 'buses', 'bushy', 'bushes', 'caring', 'care', 'universal', 'universally', 'study', 'studying', 'studies', 'better'] ---> runner
# ['running', 'runner', 'ran', 'flies', 'flying', 'happily', 'happiness', 'cats', 'dogs', 'buses', 'bushy', 'bushes', 'caring', 'care', 'universal', 'universally', 'study', 'studying', 'studies', 'better'] ---> ran
# ['running', 'runner', 'ran', 'flies', 'flying', 'happily', 'happiness', 'cats', 'dogs', 'buses', 'bushy', 'bushes', 'caring', 'care', 'universal', 'universally', 'study', 'studying', 'studies', 'better'] ---> fli
# ...

# %%
# stemming: based on rule removes suffixs
# converts words into lowercase use lematizations

# %%
words = [
    "running", "runner", "ran", "flies", "flying", "happily", "happiness",
    "cats", "dogs", "buses", "bushy", "bushes", "caring", "care",
    "universal", "universally", "study", "studying", "studies", "better"
]

for word in words:
    print(f'{word} ---> {stemmer.stem(word)}')
# Out:
# running ---> run
# runner ---> runner
# ran ---> ran
# flies ---> fli
# flying ---> fli
# happily ---> happili
# happiness ---> happi
# cats ---> cat
# dogs ---> dog
# buses ---> buse
# bushy ---> bushi
# bushes ---> bush
# caring ---> care
# care ---> care
# universal ---> univers
# universally ---> univers
# study ---> studi
# studying ---> studi
# studies ---> studi
# better ---> better

# %%
from nltk.stem import PorterStemmer

porter_stemmer = PorterStemmer()

# %%
# SnowballSteammer: 
# support multiple language 
# skkep the actual case of words
# ignores 
from nltk.stem import SnowballStemmer

snowball_stemmer  = SnowballStemmer('english',ignore_stopwords=True)

# %%
snowball_words = [
    "running", "runner", "ran", "flies", "flying", "happily", "happiness",
    "cats", "dogs", "buses", "bushy", "bushes", "caring", "care",
    "universal", "universally", "study", "studying", "studies", "better",'a','the','are','and'
]
# snowball_stemmer = SnowballStemmer(language="english")
# snowball_stemmed_words = [snowball_stemmer.stem(word) for word in snowball_words]
for word in words:
    print(f'{word} --> {snowball_stemmer.stem(word)}')
# Out:
# running --> run
# runner --> runner
# ran --> ran
# flies --> fli
# flying --> fli
# happily --> happili
# happiness --> happi
# cats --> cat
# dogs --> dog
# buses --> buse
# bushy --> bushi
# bushes --> bush
# caring --> care
# care --> care
# universal --> univers
# universally --> univers
# study --> studi
# studying --> studi
# studies --> studi
# better --> better

# %%
snowball_stemmer.stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
stop_words = stopwords.words('english')
# stop_words
snowball_stemmer = SnowballStemmer('english', ignore_stopwords=True)
snowball_stemmer.stopwords = stop_words
# snowball_stemmer.stopwords  
for word in snowball_words:
    print(word,snowball_stemmer.stem(word))
# Out:
# running run
# runner runner
# ran ran
# flies fli
# flying fli
# happily happili
# happiness happi
# cats cat
# dogs dog
# buses buse
# bushy bushi
# bushes bush
# caring care
# care care
# universal univers
# universally univers
# study studi
# studying studi
# studies studi
# better better
# a a
# the the
# are are
# and and

# %%
snowball_stemmer.stemmer  #it uses stopword but no use.
