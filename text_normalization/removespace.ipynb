# %%
with open('data.txt','r') as file:
    data = file.read()
    words = data.split()
    data =' '.join(words)

# %%
print(data)
# Out:
# hello my naem is rajrajeshwarikhatawate If the optional argument count is given, only the first count occurrences are replaced.

# %%
s = 'open    file'
s1 = s.split()
print(s1)
# Out:
# ['open', 'file']
