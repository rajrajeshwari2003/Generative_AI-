# %%
file = open("data.txt", "r")

data = file.read()
print(data)

file.close()
# Out:
# Hello My naem is RAjraj!/eshwariKhatawate

# %%
# Step 1: Read the file
with open("data.txt", "r") as file:
    data = file.read()

# Step 2: Convert to lowercase
data = data.lower()

# Step 3: Write the updated text back to the same file
with open("data.txt", "w") as file:
    file.write(data)

print("File updated successfully.")
# Out:
# File updated successfully.

# %%
# with open('data.txt', 'r+') as file:    
#     data=file.read()
#     data = data.lower()
#     file.seek(0)
#     file.write(data)
# print(data)

# %%
# with open('data.txt','r') as file:
#     data = file.read().lower()
    #   for char in data:
    #   if char 
# with open('data.txt','w') as file:
#     data = file.write(data)
