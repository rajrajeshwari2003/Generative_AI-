# %%
from textblob import TextBlob as tb #it accept str, stroning the str inside str
# not 100% accurate, if it doesn't understand it ll give wrong o/p

# %%
s = 'corretng the wrong wors from the givn txt'
crt_wd = tb(s).correct() #.correct to correct the given wrong str
print(crt_wd,type(crt_wd))
# Out:
# correcting the wrong words from the give txt <class 'textblob.blob.TextBlob'>

# %%
s = 'corretng the wrong wors from the givn txt if it havv a wrog txt'
crt_wd = tb(s).correct() #.correct to correct the given wrong str
print(crt_wd,type(crt_wd))
# Out:
# correcting the wrong words from the give txt if it have a wrong txt <class 'textblob.blob.TextBlob'>
